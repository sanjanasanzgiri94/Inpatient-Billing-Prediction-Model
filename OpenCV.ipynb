# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanasanzgiri94/Inpatient-Billing-Prediction-Model/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
a = cv2.imread("/content/sample_data/golden-retriever-dog-sitting-isolated-white-24750809.webp",0)
print(a)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
a.shape
a.ndim
# Out:
# 3

# %%
cv2_imshow(a)
cv2.waitKey(2220)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=600x900>

# %%
a = cv2.imread("/content/sample_data/golden-retriever-dog-sitting-isolated-white-24750809.webp",1)
print(a)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(a.shape)
r = a[:, :, 0]
print(r)
g = a[:,:,1]
print(g)
b = a[:,:,2]
# Out:
# (900, 600, 3)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
cv2_imshow(a)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2_imshow(r)
cv2.waitKey(0)
cv2.destroyAllWindows()

#similar can be done for g and b by replacing r by g or b; gives similar b&w image
# Out:
# <PIL.Image.Image image mode=RGB size=600x900>
# <PIL.Image.Image image mode=L size=600x900>
